# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
fat_data = pd.read_csv('../data/prueba_fat_hw_decodificadores/prueba_fat_hw_decodificadores.csv')

# %%
fat_data.head(1)
# Out:
#                              fulcrum_id               created_at  \
# 0  df5942ce-8a36-438c-b0a2-57470de53053  2021-11-26 09:45:02 UTC
#
#                 updated_at                       created_by  \
# 0  2022-01-19 15:43:56 UTC  zbarcenilla@alaudaingenieria.es
#
#                         updated_by        system_created_at  \
# 0  zbarcenilla@alaudaingenieria.es  2021-11-26 10:09:10 UTC
#
#          system_updated_at  version  status  project  assigned_to  latitude  \
# 0  2022-01-19 15:49:10 UTC        2     NaN      NaN          NaN       NaN
#
#    longitude         geometry                     pruebas_fat        date  \
# 0        NaN  POINT (0.0 0.0)  Decodificador de Video HD y SD  2021-11-26
#
#   revision             documento     codigo_documento activo_mc30  \
# 0      V01  PROTOCOLO PRUEBA FAT  ATC_FAT_CPD_004_V01    CCCMAW04
#
#                         tipo_de_equipo            dispositivo_hardware  \
# ...

# %%
fat_data.columns
# Out:
# Index(['fulcrum_id', 'created_at', 'updated_at', 'created_by', 'updated_by',
#        'system_created_at', 'system_updated_at', 'version', 'status',
#        'project', 'assigned_to', 'latitude', 'longitude', 'geometry',
#        'pruebas_fat', 'date', 'revision', 'documento', 'codigo_documento',
#        'activo_mc30', 'tipo_de_equipo', 'dispositivo_hardware',
#        'marca_y_modelo', 'capitulo_ppt', 'referencia_presupuesto',
#        'n_de_serie', 'mac', 'ip', 'version_equipo', 'version_fw', 'marcado_ce',
#        'marcado_ce_caption', 'marcado_ce_url',
#        'comprobacion_visual_del_material_acopiado_fat', 'observaciones_visual',
#        'comprobacion_de_conexion_a_la_red_electrica_fat',
#        'observaciones_red_electrica',
#        'comprobacion_de_la_comunicacion_en_red_fat',
#        'observaciones_link_ethernet', 'comprobacion_del_canal_hdmi_fat',
#        'observaciones_canal_hdmi', 'comprobacion_del_canal_dp_fat',
# ...

# %%
fulcrum_metadata = ['fulcrum_id', 'created_at', 'updated_at', 'created_by', 'updated_by',
       'system_created_at', 'system_updated_at', 'version', 'status',
       'project', 'assigned_to', 'latitude', 'longitude', 'geometry']
